# %% [markdown]
# # EDA

# %%
import os

import numpy as np
import pandas as pd

import plotly.express as ex
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Collecting seaborn
#   Using cached seaborn-0.12.2-py3-none-any.whl (293 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in /home/jylee/miniconda3/envs/recommender/lib/python3.10/site-packages (from seaborn) (1.24.3)
# Requirement already satisfied: pandas>=0.25 in /home/jylee/miniconda3/envs/recommender/lib/python3.10/site-packages (from seaborn) (2.0.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /home/jylee/miniconda3/envs/recommender/lib/python3.10/site-packages (from seaborn) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/jylee/miniconda3/envs/recommender/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /home/jylee/miniconda3/envs/recommender/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/jylee/miniconda3/envs/recommender/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.39.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/jylee/miniconda3/envs/recommender/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /home/jylee/miniconda3/envs/recommender/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /home/jylee/miniconda3/envs/recommender/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/jylee/miniconda3/envs/recommender/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /home/jylee/miniconda3/envs/recommender/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/jylee/miniconda3/envs/recommender/lib/python3.10/site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /home/jylee/miniconda3/envs/recommender/lib/python3.10/site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in /home/jylee/miniconda3/envs/recommender/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.12.2

# %% [markdown]
# params

# %%
DATA_DIR = '../../../datasets/kaggle/titanic/'

# %% [markdown]
# ## import data

# %%
df = pd.read_csv(os.path.join(DATA_DIR, 'train.csv'))
print(df.shape)
df.head()
# Out:
# (891, 12)
#    PassengerId  Survived  Pclass
# 0            1         0       3  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp
# 0                            Braund, Mr. Owen Harris    male  22.0      1  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
num_cols = []
cat_cols = []

for colname in df.columns:
    if df[colname].dtype in ['int64', 'float64']:
        num_cols.append(colname)
    else:
        cat_cols.append(colname)

len(num_cols), len(cat_cols)
# Out:
# (7, 5)

# %% [markdown]
# 수치형 데이터의 분포

# %%
df[num_cols].describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp
# count   891.000000  891.000000  891.000000  714.000000  891.000000  \
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.hist(column=num_cols)
plt.tight_layout()
plt.show()

# %% [markdown]
# - Survived, Pclass는 범주형인데 순서가 있는 범주형이고
# - Age는 비교적 정규분포이며, 10-30대가 많은 편
# - SibSp, Parch, Fare는 0 쪽에 몰려 있음 !preprocessing: transformation

# %% [markdown]
# 범주형 데이터의 분포

# %%
df[cat_cols].describe()
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
df[cat_cols].head()
# Out:
#                                                 Name     Sex
# 0                            Braund, Mr. Owen Harris    male  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male
#
#              Ticket Cabin Embarked
# 0         A/5 21171   NaN        S
# 1          PC 17599   C85        C
# 2  STON/O2. 3101282   NaN        S
# 3            113803  C123        S
# 4            373450   NaN        S

# %% [markdown]
# - sex, embarked !preprocessing: one-hot Encoding
# - cabin -> split data !preprocessing: character, number
# - name, ticket - high-level preprocess or not-use

# %% [markdown]
# # preprocessing

# %%
df = pd.concat([df, pd.get_dummies(df[['Sex', 'Embarked']])], axis=1)
df = df.drop(columns=['Sex', 'Embarked'])
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Sex_female', 'Sex_male', 'Embarked_C',
#        'Embarked_Q', 'Embarked_S'],
#       dtype='object')

# %%
df = df.drop(columns=['Name', 'Ticket'])
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare',
#        'Cabin', 'Sex_female', 'Sex_male', 'Embarked_C', 'Embarked_Q',
#        'Embarked_S'],
#       dtype='object')

# %%
## !! cabin 전처리도 은근 빡쎔 걍 패스하자
# df['Cabin_area'] = df['Cabin'].apply(lambda x: x[0] if type(x) != float else np.nan)
# df['Cabin_number'] = df['Cabin'].apply(lambda x: int(x[1:]) if type(x) != float else np.nan)
df = df.drop(columns='Cabin')
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare',
#        'Sex_female', 'Sex_male', 'Embarked_C', 'Embarked_Q', 'Embarked_S'],
#       dtype='object')

# %% [markdown]
# # Correlation analysis with Pearson

# %%
df_corr.reset_index()
# Out:
#           index  PassengerId  Survived    Pclass       Age     SibSp
# 0   PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527  \
# 1      Survived    -0.005007  1.000000 -0.338481 -0.077221 -0.035322
# 2        Pclass    -0.035144 -0.338481  1.000000 -0.369226  0.083081
# 3           Age     0.036847 -0.077221 -0.369226  1.000000 -0.308247
# 4         SibSp    -0.057527 -0.035322  0.083081 -0.308247  1.000000
# 5         Parch    -0.001652  0.081629  0.018443 -0.189119  0.414838
# 6          Fare     0.012658  0.257307 -0.549500  0.096067  0.159651
# 7    Sex_female    -0.042939  0.543351 -0.131900 -0.093254  0.114631
# 8      Sex_male     0.042939 -0.543351  0.131900  0.093254 -0.114631
# 9    Embarked_C    -0.001205  0.168240 -0.243292  0.036261 -0.059528
# 10   Embarked_Q    -0.033606  0.003650  0.221009 -0.022405 -0.026354
# 11   Embarked_S     0.022148 -0.155660  0.081720 -0.032523  0.070941
#
#        Parch      Fare  Sex_female  Sex_male  Embarked_C  Embarked_Q
# 0  -0.001652  0.012658   -0.042939  0.042939   -0.001205   -0.033606  \
# 1   0.081629  0.257307    0.543351 -0.543351    0.168240    0.003650
# 2   0.018443 -0.549500   -0.131900  0.131900   -0.243292    0.221009
# 3  -0.189119  0.096067   -0.093254  0.093254    0.036261   -0.022405
# 4   0.414838  0.159651    0.114631 -0.114631   -0.059528   -0.026354
# 5   1.000000  0.216225    0.245489 -0.245489   -0.011069   -0.081228
# 6   0.216225  1.000000    0.182333 -0.182333    0.269335   -0.117216
# 7   0.245489  0.182333    1.000000 -1.000000    0.082853    0.074115
# 8  -0.245489 -0.182333   -1.000000  1.000000   -0.082853   -0.074115
# 9  -0.011069  0.269335    0.082853 -0.082853    1.000000   -0.148258
# 10 -0.081228 -0.117216    0.074115 -0.074115   -0.148258    1.000000
# 11  0.063036 -0.166603   -0.125722  0.125722   -0.778359   -0.496624
#
#     Embarked_S
# 0     0.022148
# 1    -0.155660
# 2     0.081720
# 3    -0.032523
# 4     0.070941
# 5     0.063036
# 6    -0.166603
# 7    -0.125722
# 8     0.125722
# 9    -0.778359
# 10   -0.496624
# 11    1.000000

# %%
df_corr = df.corr()

plt.figure(figsize = (8,8))
sns.heatmap(df_corr, annot=True, cmap='RdBu_r')
plt.show()
# ex.imshow(df_corr, color_continuous_scale='RdBu_r', text_auto=True, width=1000, height=1000)
## https://plotly.com/python/heatmaps/

# %% [markdown]
# 여성이 많이 살고, 남성이 많이 죽음, S 에서 탄 사람이 많이 죽음, pclass와도 음의 관계. fare가 높을수록 많이 살음.

# %%
np.random.normal(0, 1, 418)
# Out:
# array([ 0.36918467,  0.10279056,  0.45578922, -1.28332953, -0.71381978,
#         0.78324948, -0.77755147, -0.39581141,  0.75562982,  0.18450472,
